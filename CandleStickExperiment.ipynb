# %%
import os
import tarfile
from six.moves import urllib
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib import style
style.use("ggplot")
INPUT_DIR = "input"

# %%
csv_path = os.path.join(INPUT_DIR, "crypto-markets.csv")
cryptoMarketData = pd.read_csv(csv_path)
cryptoMarketData.head()
# Out:
#   symbol        date    open    high     low   close  volume      market  \
# 0    BTC  2013-04-28  135.30  135.98  132.10  134.21       0  1500520000
# 1    BTC  2013-04-29  134.44  147.49  134.00  144.54       0  1491160000
# 2    BTC  2013-04-30  144.00  146.93  134.05  139.00       0  1597780000
# 3    BTC  2013-05-01  139.00  139.89  107.72  116.99       0  1542820000
# 4    BTC  2013-05-02  116.38  125.60   92.28  105.21       0  1292190000
#
#       name  ranknow
# 0  Bitcoin        1
# 1  Bitcoin        1
# 2  Bitcoin        1
# 3  Bitcoin        1
# 4  Bitcoin        1

# %%
cryptoMarketData.describe()
# Out:
#                open          high           low         close        volume  \
# count  6.581670e+05  6.581670e+05  6.581670e+05  6.581670e+05  6.581670e+05
# mean   1.412778e+02  1.685448e+02  1.168656e+02  1.408856e+02  2.551634e+06
# std    5.996828e+03  7.485553e+03  4.590897e+03  5.932229e+03  9.002713e+07
# min    1.000000e-10  1.300000e-10  9.200000e-14  0.000000e+00  0.000000e+00
# 25%    3.730000e-04  4.350000e-04  3.230000e-04  3.730000e-04  1.700000e+01
# 50%    5.804000e-03  6.721000e-03  5.036000e-03  5.815000e-03  2.720000e+02
# 75%    8.075150e-02  9.338050e-02  7.052450e-02  8.098300e-02  5.546000e+03
# max    1.531520e+06  1.661230e+06  7.324670e+05  1.532950e+06  2.113600e+10
#
#              market        ranknow
# count  6.581670e+05  658167.000000
# mean   7.285711e+07     634.677293
# std    2.022887e+09     377.459513
# min    0.000000e+00       1.000000
# 25%    5.894000e+03     318.000000
# 50%    6.421100e+04     631.000000
# ...

# %%
cryptoMarketData.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 658167 entries, 0 to 658166
# Data columns (total 10 columns):
# symbol     658167 non-null object
# date       658167 non-null object
# open       658167 non-null float64
# high       658167 non-null float64
# low        658167 non-null float64
# close      658167 non-null float64
# volume     658167 non-null int64
# market     658167 non-null int64
# name       658167 non-null object
# ranknow    658167 non-null int64
# dtypes: float64(4), int64(3), object(3)
# memory usage: 50.2+ MB

# %%
# Out:
# <function matplotlib.pyplot.show>
